# %%
import pandas as pd

# %%
tb = pd.read_csv("tb_burden_country.csv")

# %%
tb.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...

# %%
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5120 entries, 0 to 5119
# Data columns (total 47 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Country or territory name                                                                       5120 non-null   object
#  1   ISO 2-character country/territory code                                                          5096 non-null   object
#  2   ISO 3-character country/territory code                                                          5120 non-null   object
#  3   ISO numeric country/territory code                                                              5120 non-null   int64
#  4   Region                                                                                          5120 non-null   object
# ...

# %%
tb.describe().T
# Out:
#                                                      count          mean  \
# ISO numeric country/territory code                  5120.0  4.335766e+02
# Year                                                5120.0  2.001549e+03
# Estimated total population number                   5120.0  2.915671e+07
# Estimated prevalence of TB (all forms) per 100 ...  5120.0  1.943861e+02
# Estimated prevalence of TB (all forms) per 100 ...  5100.0  1.018154e+02
# Estimated prevalence of TB (all forms) per 100 ...  5100.0  3.210064e+02
# Estimated prevalence of TB (all forms)              5120.0  6.654332e+04
# Estimated prevalence of TB (all forms), low bound   5100.0  4.615915e+04
# Estimated prevalence of TB (all forms), high bound  5100.0  9.319791e+04
# Estimated mortality of TB cases (all forms, exc...  5120.0  2.017443e+01
# Estimated mortality of TB cases (all forms, exc...  5120.0  1.337948e+01
# Estimated mortality of TB cases (all forms, exc...  5120.0  2.739392e+01
# ...
